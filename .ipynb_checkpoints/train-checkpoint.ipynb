# %%
from roboflow import Roboflow
rf = Roboflow(api_key="u9NOqedUxd3Q4TIpMzNt")
project = rf.workspace("elinswork").project("classaction-datasets")
dataset = project.version(2).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.88, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to ClassAction-Datasets-2 in yolov8:: 100%|██████████| 2126/2126 [00:00<00:00, 7822.64it/s]

# %%
from ultralytics import checks
checks()
# Out:
# Ultralytics YOLOv8.0.105 🚀 Python-3.10.9 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Setup complete ✅ (12 CPUs, 7.8 GB RAM, 142.8/1006.9 GB disk)

# %%
from ultralytics import YOLO
model = YOLO("yolov8m.pt")
model.train(
    data="conf.yaml",
    imgsz=640,
    batch=4,
    epochs=100,
    optimizer='Adam',
)
# Out:
# Ultralytics YOLOv8.0.105 🚀 Python-3.10.9 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %%
model.export(format="onnx",batch=1,simplify=True)
# Out:
# Ultralytics YOLOv8.0.105 🚀 Python-3.10.9 torch-2.0.1+cu118 CPU
# Model summary (fused): 218 layers, 25850182 parameters, 0 gradients, 78.7 GFLOPs
#
# PyTorch: starting from runs/detect/train/weights/best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 22, 8400) (49.6 MB)
#
# ONNX: starting export with onnx 1.14.0 opset 17...
# ONNX: simplifying with onnxsim 0.4.28...
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# ONNX: export success ✅ 6.3s, saved as runs/detect/train/weights/best.onnx (98.8 MB)
#
# Export complete (8.0s)
# Results saved to /home/elin/modelTraining/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train/weights/best.onnx imgsz=640 data=conf.yaml
# ...

# %%
# !yolo export model=./runs/detect/train/weights/best.pt format=engine device=0
# Out:
# Ultralytics YOLOv8.0.105 🚀 Python-3.10.9 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 218 layers, 25850182 parameters, 0 gradients, 78.7 GFLOPs
#
# PyTorch: starting from runs/detect/train/weights/best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 22, 8400) (49.6 MB)
#
# ONNX: starting export with onnx 1.14.0 opset 17...
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: simplifying with onnxsim 0.4.28...
# ONNX: export success ✅ 5.4s, saved as runs/detect/train/weights/best.onnx (98.8 MB)
#
# TensorRT: starting export with TensorRT 8.6.1...
# [05/21/2023-16:08:13] [TRT] [I] [MemUsageChange] Init CUDA: CPU +2, GPU +0, now: CPU 567, GPU 2340 (MiB)
# ...
