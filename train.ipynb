# %%
from roboflow import Roboflow
rf = Roboflow(api_key="V0mb5NHsVNFjqpiax6gr")
project = rf.workspace("lambda98").project("student_behavior")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.190, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to Student_Behavior-1 in yolov8:: 100%|██████████| 472/472 [00:00<00:00, 10833.96it/s]

# %%
from ultralytics import checks
checks()
# Out:
# Ultralytics YOLOv8.0.190 🚀 Python-3.9.13 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3080 Ti Laptop GPU, 16384MiB)
# Setup complete ✅ (24 CPUs, 15.5 GB RAM, 249.9/1006.9 GB disk)

# %%
from ultralytics import YOLO
model = YOLO("yolov8l.pt")
model.train(
    data="./conf.yaml",
    imgsz=640,
    batch=8,
    epochs=200,
    optimizer='Adam',
)
# Out:
# New https://pypi.org/project/ultralytics/8.0.192 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.190 🚀 Python-3.9.13 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3080 Ti Laptop GPU, 16384MiB)
# ...

# %%
# !yolo export model=/root/runs/detect/train23/weights/best.pt format=engine device=0 batch=1
# Out:
# Ultralytics YOLOv8.0.190 🚀 Python-3.9.13 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3080 Ti Laptop GPU, 16384MiB)
# Model summary (fused): 268 layers, 43614318 parameters, 0 gradients, 164.9 GFLOPs
#
# PyTorch: starting from '/root/runs/detect/train23/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 14, 8400) (83.6 MB)
#
# ONNX: starting export with onnx 1.14.0 opset 17...
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: simplifying with onnxsim 0.4.33...
# ONNX: export success ✅ 5.2s, saved as '/root/runs/detect/train23/weights/best.onnx' (166.6 MB)
#
# TensorRT: starting export with TensorRT 8.6.1...
# [10/04/2023-10:58:02] [TRT] [I] [MemUsageChange] Init CUDA: CPU +2, GPU +0, now: CPU 858, GPU 2042 (MiB)
# ...

# %%
# !trtexec --onnx=/root/runs/detect/train23/weights/best.onnx --saveEngine=/root/runs/detect/train23/weights/best.plan
# Out:
# &&&& RUNNING TensorRT.trtexec [TensorRT v8601] # trtexec --onnx=/root/runs/detect/train23/weights/best.onnx --saveEngine=/root/runs/detect/train23/weights/best.plan
# [10/04/2023-11:00:38] [I] === Model Options ===
# [10/04/2023-11:00:38] [I] Format: ONNX
# [10/04/2023-11:00:38] [I] Model: /root/runs/detect/train23/weights/best.onnx
# [10/04/2023-11:00:38] [I] Output:
# [10/04/2023-11:00:38] [I] === Build Options ===
# [10/04/2023-11:00:38] [I] Max batch: explicit batch
# [10/04/2023-11:00:38] [I] Memory Pools: workspace: default, dlaSRAM: default, dlaLocalDRAM: default, dlaGlobalDRAM: default
# [10/04/2023-11:00:38] [I] minTiming: 1
# [10/04/2023-11:00:38] [I] avgTiming: 8
# [10/04/2023-11:00:38] [I] Precision: FP32
# [10/04/2023-11:00:38] [I] LayerPrecisions:
# [10/04/2023-11:00:38] [I] Layer Device Types:
# [10/04/2023-11:00:38] [I] Calibration:
# [10/04/2023-11:00:38] [I] Refit: Disabled
# [10/04/2023-11:00:38] [I] Version Compatible: Disabled
# ...

# %%
# !mv /root/runs/detect/train23 ./runs/detect/train23
